# %% [markdown]
# <a href="https://colab.research.google.com/github/porkostomus/jupyter/blob/master/linear_equations_graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear equations: graphs
#
# ## Wilbur's plane
#
# Wilbur landed his plane.
#
# The plane's elevation relative to the ground (in meters) as a function of time (in seconds) is graphed.

# %%
import matplotlib.pyplot as plt
from sympy import *

# %%
plt.xkcd()

x, y = symbols('x y')

data = { 
     'x' : [0, 100, 500, 1200, 1700],
     'y' : [8500, 8000, 6000, 2500, 0]
}

x1 = data['x'][0]
x2 = data['x'][1]
y1 = data['y'][0]
y2 = data['y'][1]
m = (y2 - y1)/(x2 - x1)
PointSlope = Eq(y - y2, m * (x - x2))

plt.plot(data['x'], data['y'])
plt.xlabel('Time (seconds)')
plt.ylabel('Elevation (meters)')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# **How fast did the plane descend in meters per second?**

# %%
m = (data['y'][1] - data['y'][0]) / (data['x'][1] - data['x'][0])

# %%
m
# Out:
# -5.0

# %% [markdown]
# **How long did it take the plane to land?**

# %%
x, y = symbols('x y')
PointSlope = Eq(y - data['y'][1], m * (x - data['x'][1]))
solveset(PointSlope.subs(y, 0), x)
# Out:
# {1700.0}

# %% [markdown]
# ## Rip van Winkle's beard growth
#
# Rip van Winkle has fallen asleep for a very long time.
#
# The length of his beard (in millimeters) as a function of time (in weeks) is graphed.

# %%
data = { 
     'x' : [0, 10, 20, 30],
     'y' : [10, 35, 60, 85]
}

plt.plot(data['x'], data['y'])
plt.xlabel('Time (weeks)')
plt.ylabel('Beard length (millimeters)')
plt.grid(True)
plt.show()

# %% [markdown]
# **How long did it take each time Rip van Winkle's beard grew by $5$ millimeters?**

# %%
5 / ((data['y'][1] - data['y'][0]) / 
     (data['x'][1] - data['x'][0]))
# Out:
# 2.0

# %% [markdown]
# ## Karl's truck fuel
#
# Karl set out to Alaska in his truck.
# The amount of fuel remaining in the truck's tank (in liters) as a function of distance driven (in kilometers) is graphed.

# %%
x, y = symbols('x y')
data = { 
     'x' : [0, 750],
     'y' : [500, 50]
}

x1 = data['x'][0]
x2 = data['x'][1]
y1 = data['y'][0]
y2 = data['y'][1]
m = (y2 - y1)/(x2 - x1)
PointSlope = Eq(y - y2, m * (x - x2))

plt.plot(data['x'], data['y'])
plt.xlabel('Distance (kilometers)')
plt.ylabel('Fuel (liters)')
plt.grid(True)
plt.show()

# %% [markdown]
# **How many liters per kilometer did the truck consume its fuel?**

# %%
m
# Out:
# -0.6

# %% [markdown]
# ## Suraj's pizza
#
# Suraj took a slice of pizza from the freezer and put it in the oven.
#
# The pizza's temperature (in degrees Celsius) as a function of time (in minutes) is graphed.

# %%
x, y = symbols('x y')
data = { 
     'x' : [0.75, 4.5],
     'y' : [0, 30]
}

x1 = data['x'][0]
x2 = data['x'][1]
y1 = data['y'][0]
y2 = data['y'][1]
m = (y2 - y1)/(x2 - x1)
PointSlope = Eq(y - y2, m * (x - x2))

plt.plot(data['x'], data['y'])
plt.xlabel('Time (minutes)')
plt.ylabel('Temperature (degrees Celsius)')
plt.grid(True)
plt.show()

# %% [markdown]
# **What was the pizza's temperature after $2$ minutes?**

# %%
solveset(PointSlope.subs(x, 2))
# Out:
# {10.0}

# %% [markdown]
# ## Zane's volcano climbing
#
# While exploring a volcano, Zane heard some rumbling, so he decided to climb up out of there as quickly as he could.
#
# Zane's elevation relative to the edge of the inside of the volcano (in meters) as a function of time (in seconds) is graphed.

# %%
x, y = symbols('x y')
data = { 
     'x' : [0, 35],
     'y' : [-25, 0]
}

x1 = data['x'][0]
x2 = data['x'][1]
y1 = data['y'][0]
y2 = data['y'][1]
m = (y2 - y1)/(x2 - x1)
PointSlope = Eq(y - y2, m * (x - x2))

plt.plot(data['x'], data['y'])
plt.xlabel('Time (seconds)')
plt.ylabel('Elevation (meters)')
plt.grid(True)
plt.show()

# %% [markdown]
# **How many meters high did Zane climb every $7$ seconds?**

# %%
m * 7
# Out:
# 5.0

# %% [markdown]
# ## Sean's slushy
#
# Sean is drinking a slushy as fast as he can.
#
# The amount of slushy left in the cup (in milliliters) as a function of time (in seconds) is graphed.

# %%
x, y = symbols('x y')
data = { 
     'x' : [0, 75],
     'y' : [600, 0]
}

x1 = data['x'][0]
x2 = data['x'][1]
y1 = data['y'][0]
y2 = data['y'][1]
m = (y2 - y1)/(x2 - x1)
PointSlope = Eq(y - y2, m * (x - x2))

plt.plot(data['x'], data['y'])
plt.xlabel('Time (seconds)')
plt.ylabel('Slushy (milliliters)')
plt.grid(True)
plt.show()

# %% [markdown]
# **How many seconds did it take Sean to finish the slushy?**

# %%
solveset(PointSlope.subs(y, 0))
# Out:
# {75.0}

# %% [markdown]
# **How much slushy was in the cup initially?**

# %%
solveset(PointSlope.subs(x, 0))
# Out:
# {600.0}

# %% [markdown]
# ## Charging the battery
#
# A battery is charged.
#
# The percentage of the battery's capacity that is charged as a function of time (in minutes) is graphed.

# %%
x, y = symbols('x y')
data = { 
     'x' : [0, 30],
     'y' : [40, 100]
}

x1 = data['x'][0]
x2 = data['x'][1]
y1 = data['y'][0]
y2 = data['y'][1]
m = (y2 - y1)/(x2 - x1)
PointSlope = Eq(y - y2, m * (x - x2))

plt.plot(data['x'], data['y'])
plt.xlabel('Time (minutes)')
plt.ylabel('Capacity (percent charged)')
plt.grid(True)
plt.show()

# %% [markdown]
# **At what percent per minute is the battery charged?**

# %%
m
# Out:
# 2.0

# %%
x, y = symbols('x y')
m = 7.5
PointSlope = Eq(y - y2, m * (x - x2))
x2 = 12
y2 = 80
solveset(PointSlope.subs(x, 0))
# Out:
# {-10.0}

# %%
85/3
# Out:
# 28.333333333333332
